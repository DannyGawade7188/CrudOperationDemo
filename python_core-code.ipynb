# %% [markdown]
# <a href="https://colab.research.google.com/github/DannyGawade7188/CrudOperationDemo/blob/main/python_core-code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')

age = 25
is_student = False
has_discount_code = True

if (age < 18 or age > 65) and not is_student or has_discount_code:
  print("Discount applies!")
# Out:
# Hello world
